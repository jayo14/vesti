# %% [markdown]
# # 01 — Person Detection (YOLOv11n)
#
# Validate detection against 3–5 sample images. Confirms single-person requirement and multi-person rejection.

# %%
import sys; sys.path.insert(0, '..')
from vision_engine.main import app
from fastapi.testclient import TestClient
c = TestClient(app)

# %%
# Point SAMPLE to a real full-body photo path.
from PIL import Image
import base64, io
def b64(path):
    b=io.BytesIO(); Image.open(path).save(b,'PNG'); return base64.b64encode(b.getvalue()).decode()
# SAMPLE = 'samples/person.jpg'
# r = c.post('/v1/detect', json={'image_base64': b64(SAMPLE)})
# print(r.status_code, r.json())
