# %% [markdown]
# # 04 — Measurements Estimator
#
# Spot-check geometry against a known-height subject.

# %%
import sys; sys.path.insert(0, '..')
from vision_engine.main import app
from fastapi.testclient import TestClient
c = TestClient(app)
# landmarks = [...]  # from /v1/pose
# r = c.post('/v1/measurements', json={'landmarks': landmarks, 'height_cm': 172})
# print(r.json())
