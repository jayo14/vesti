# %% [markdown]
# # 05 — Human Parsing (SCHP/SegFormer)
#
# Validate per-region masks feed measurements.

# %%
import sys; sys.path.insert(0, '..')
from vision_engine.main import app
from fastapi.testclient import TestClient
c = TestClient(app)
# r = c.post('/v1/parse', json={'image_base64': b64(PERSON)})
# print([reg['region'] for reg in r.json()['regions']])
