# %% [markdown]
# # 06 — Garment Segmentation (SAM2 + Grounding DINO)
#
# Validate text-prompted cutout + polygon; compare to RMBG-2.0 product cleanup.

# %%
import sys; sys.path.insert(0, '..')
from vision_engine.main import app
from fastapi.testclient import TestClient
c = TestClient(app)
# r = c.post('/v1/garment/segment', json={'image_base64': b64(GARMENT), 'prompt':'dress'})
# print(r.json().get('garment_type'), r.json().get('confidence'))
