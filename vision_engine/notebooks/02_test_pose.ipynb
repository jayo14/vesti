# %% [markdown]
# # 02 — Pose (MediaPipe)
#
# Confirm 33 landmarks and key-joint confidence. Expect LowPoseConfidenceError on cropped/blurry photos.

# %%
import sys; sys.path.insert(0, '..')
from vision_engine.main import app
from fastapi.testclient import TestClient
c = TestClient(app)
# r = c.post('/v1/pose', json={'image_base64': b64(SAMPLE)})
# print(r.status_code, len(r.json()['landmarks']), r.json()['confidence'])
