# %% [markdown]
# # 03 — Virtual Try-On (IDM-VTON)
#
# Core validation: feed a real person photo + real garment cutout and confirm pixels are preserved (face/body not hallucinated). Requires a hosted provider or local weights.

# %%
import sys; sys.path.insert(0, '..')
from vision_engine.main import app
from fastapi.testclient import TestClient
c = TestClient(app)
# payload = {'person_image': {'image_base64': b64(PERSON)},
#            'garment_cutout': {'image_base64': b64(GARMENT)},
#            'measurements': {...}, 'garment_metadata': {'fit_type':'regular'}}
# r = c.post('/v1/tryon', json=payload)
# print(r.status_code, r.json().get('model'), r.json().get('fit_analysis'))
