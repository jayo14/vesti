# %% [markdown]
# # 07 — Enhancement (Real-ESRGAN)
#
# Validate upscale pass on a try-on output.

# %%
import sys; sys.path.insert(0, '..')
from vision_engine.main import app
from fastapi.testclient import TestClient
c = TestClient(app)
# r = c.post('/v1/enhance', json={'image_base64': b64(TRYON), 'scale': 2})
# print(r.status_code, r.json().get('model'))
